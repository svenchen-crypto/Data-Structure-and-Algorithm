# %% [markdown]
# ## 24. Swap Nodes in Pairs
#
# ### Description
#
# Consider the following implementation of linked list:

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %% [markdown]
# Given a linked list, swap every two adjacent nodes and return its head. You must solve the problem without modifying the values in the list's nodes (i.e., only nodes themselves may be changed.)
#
# #### Example
#
# Input: head = [1,2,3,4]
#
# Output: [2,1,4,3]
#
# Explanation:
#
# ![image.png](attachment:image.png)
#
# Input: head = []
#
# Output: []
#
# Input: head = [1,2,3]
#
# Output: [2,1,3]
#
# ### Solution
#
# #### 1. Recursion
#
# This problem is similar to reversing linked list,

# %%
def swapPairsRecursive(head):
    pass

# %% [markdown]
# #### 2. Two pointers
#
# Like all linked list related problems, this problem can be solved using two pointers.

# %%
def swapPairsNonRecursive(head):
    pass
